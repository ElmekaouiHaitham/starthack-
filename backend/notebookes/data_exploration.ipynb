# %%
import pandas as pd
import json
import os

# Load the datasets
supplierss_df = pd.read_csv('../data/suppliers.csv')

supplierss_df.head()
# Out:
#   supplier_id           supplier_name category_l1  \
# 0    SUP-0001  Dell Enterprise Europe          IT
# 1    SUP-0001  Dell Enterprise Europe          IT
# 2    SUP-0001  Dell Enterprise Europe          IT
# 3    SUP-0001  Dell Enterprise Europe          IT
# 4    SUP-0001  Dell Enterprise Europe          IT
#
#                             category_l2 country_hq  \
# 0                               Laptops         DE
# 1                   Mobile Workstations         DE
# 2                              Monitors         DE
# 3                      Docking Stations         DE
# 4  Replacement / Break-Fix Pool Devices         DE
#
#               service_regions currency pricing_model  quality_score  \
# 0  DE;FR;NL;BE;AT;CH;IT;ES;PL      EUR        tiered             87
# 1  DE;FR;NL;BE;AT;CH;IT;ES;PL      EUR        tiered             85
# 2  DE;FR;NL;BE;AT;CH;IT;ES;PL      EUR        tiered             87
# 3  DE;FR;NL;BE;AT;CH;IT;ES;PL      EUR        tiered             85
# ...

# %%
supplierss_df[supplierss_df['is_restricted']]['restriction_reason']
# Out:
# 28    Restricted for selected categories and countri...
# 29    Restricted for selected categories and countri...
# Name: restriction_reason, dtype: object

# %%
suppliers_agmanted = pd.read_csv('../data/merged.csv')

suppliers_agmanted.head()
# Out:
#   supplier_id           supplier_name country_hq             service_regions  \
# 0    SUP-0001  Dell Enterprise Europe         DE  DE;FR;NL;BE;AT;CH;IT;ES;PL
# 1    SUP-0001  Dell Enterprise Europe         DE  DE;FR;NL;BE;AT;CH;IT;ES;PL
# 2    SUP-0001  Dell Enterprise Europe         DE  DE;FR;NL;BE;AT;CH;IT;ES;PL
# 3    SUP-0001  Dell Enterprise Europe         DE  DE;FR;NL;BE;AT;CH;IT;ES;PL
# 4    SUP-0001  Dell Enterprise Europe         DE  DE;FR;NL;BE;AT;CH;IT;ES;PL
#
#   pricing_model  capacity_per_month  quality_score  risk_score  esg_score  \
# 0        tiered               18000             85          17         68
# 1        tiered               18000             85          17         68
# 2        tiered               18000             85          17         68
# 3        tiered               18000             85          17         68
# 4        tiered               18000             85          17         68
#
# ...
